# %%
#importing the libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing the dataset

df = pd.read_csv('C:/Users/oyedeepak/Downloads/Assignment/Multi Linear Regression/ToyotaCorolla.csv', encoding='unicode_escape')

# %%
df.drop(df.columns[0], axis =1, inplace = True)
df.head()
# Out:
#                                             Model  Price  Age_08_04  \
# 0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color   Color  ...  \
# 0         10      2002  46986    Diesel  90          1    Blue  ...
# 1         10      2002  72937    Diesel  90          1  Silver  ...
# 2          9      2002  41711    Diesel  90          1    Blue  ...
# 3          7      2002  48000    Diesel  90          0   Black  ...
# 4          3      2002  38500    Diesel  90          0   Black  ...
#
#    Central_Lock  Powered_Windows  Power_Steering  Radio  Mistlamps  \
# 0             1                1               1      0          0
# ...

# %%
#Creating dependent and independent variables

X= df.loc[:, ["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
Y= df.Price

X.head()
# Out:
#    Price  Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0  13500         23  46986  90  2000      3      5            210    1165
# 1  13750         23  72937  90  2000      3      5            210    1165
# 2  13950         24  41711  90  2000      3      5            210    1165
# 3  14950         26  48000  90  2000      3      5            210    1165
# 4  13750         30  38500  90  2000      3      5            210    1170

# %%
X.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %%
#Dividing data between test and train dataset

from sklearn.model_selection import train_test_split
X_train,X_test, Y_train, Y_test= train_test_split(X,Y, test_size=0.33, random_state= 5)

# %%
#applying the model

from sklearn.linear_model import LinearRegression
reg= LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred= reg.predict(X_test)

# %%
from sklearn.metrics import r2_score
score = r2_score(Y_test, Y_pred)

print('The r^2 score is', score)
# Out:
# The r^2 score is 1.0

# %%
#Using statsmodels to get r^2 score

import statsmodels.formula.api as smf
ml1= smf.ols('Price~Price+Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight', data= df).fit()

ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.463e+32
# Date:                Thu, 14 May 2020   Prob (F-statistic):               0.00
# Time:                        13:01:25   Log-Likelihood:                 35734.
# No. Observations:                1436   AIC:                        -7.145e+04
# Df Residuals:                    1426   BIC:                        -7.139e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
